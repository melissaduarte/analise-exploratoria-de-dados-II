# %% [markdown]
# <a href="https://colab.research.google.com/github/melissaduarte/analise-exploratoria-de-dados-II/blob/main/Projeto_final_AED_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ROTEIRO
# #### (baseado em aula de AED II - 13/11)
#
# 1. Importar as bibliotecas pandas e altair; OK
# 2. Criar a variável e importar as tabelas; OK
# 3. Delimitar as perguntas a serem feitas aos dados:
#
# - Qual a % de mulheres vítimas que não procuraram a polícia, só o SUS? (SINAN x SINESP por ano)
# - Qual é o perfil dessas mulheres: faixa etária x escolaridade x raça? (Calcular o dado geral e , se der tempo, por ano de 2018 a 2022)
# - Quantidade de casos por UF (fazer um mapa se der tempo) ((consultar André))
#
# 4. Conferir e limpar os dados OK
#
#   4.1. Excluir SP, RJ, MG e DF OK
#
#   4.2. Identificar outros missing data (ainda não)
#
# 5. Fazer um dataframe para ver o que temos e passar a filtrar;OK
#
# 6. O que precisamos fazer ainda
#   - Criar gráficos a partir dos data frames do SINAN e SINESP
#   - Ver a questão da PNAD com a Thanuci e como fazer um recorte mais adequado para comparar a população (com base em 10mil habitantes)
#   - Descobrir a % das vítimas que não procuraram a polícia, apenas o SUS
#   - Se der fazer a análise de UF
#   - Criar o storytelling

# %% [markdown]
# ##SINESP

# %%
import pandas as pd
import plotly.express as px

# %%
sinesp = pd.read_excel('sinesp.xlsx')

# %%
#descobrindo o tipo dos dados
sinesp.dtypes
# Out:
# Ano                           int64
# UF                           object
# Raça/Cor                     object
# Faixa etária                 object
# Escolaridade                 object
# Violência Sexual (SINESP)     int64
# População Mulheres (PNAD)    object
# dtype: object

# %%
#olhando a base
sinesp.head(10)
# Out:
#     Ano  UF  Raça/Cor     Faixa etária              Escolaridade  \
# 0  2011  AC   Amarela  60 anos ou mais             Sem instrução
# 1  2011  AC   Amarela  60 anos ou mais  Até fundamental completo
# 2  2011  AC    Branca  60 anos ou mais             Sem instrução
# 3  2011  AC    Branca  60 anos ou mais  Até fundamental completo
# 4  2011  AC    Branca  60 anos ou mais     Ensino médio completo
# 5  2011  AC    Branca  60 anos ou mais  Ensino superior completo
# 6  2011  AC  Indígena  60 anos ou mais             Sem instrução
# 7  2011  AC     Parda  60 anos ou mais             Sem instrução
# 8  2011  AC     Parda  60 anos ou mais  Até fundamental completo
# 9  2011  AC     Parda  60 anos ou mais     Ensino médio completo
#
#    Violência Sexual (SINESP) População Mulheres (PNAD)
# 0                          0                       368
# 1                          0                       185
# 2                          0                      3871
# ...

# %%
#excluir 2023

ano_a_remover = sinesp[(sinesp['Ano'] == 2023)].index

dados_sinesp = sinesp.drop(ano_a_remover)
dados_sinesp
# Out:
#         Ano  UF Raça/Cor     Faixa etária              Escolaridade  \
# 0      2011  AC  Amarela  60 anos ou mais             Sem instrução
# 1      2011  AC  Amarela  60 anos ou mais  Até fundamental completo
# 2      2011  AC   Branca  60 anos ou mais             Sem instrução
# 3      2011  AC   Branca  60 anos ou mais  Até fundamental completo
# 4      2011  AC   Branca  60 anos ou mais     Ensino médio completo
# ...     ...  ..      ...              ...                       ...
# 24112  2022  TO    Parda     00 a 17 anos             Sem instrução
# 24113  2022  TO    Parda     00 a 17 anos  Ensino superior completo
# 24114  2022  TO    Preta     00 a 17 anos             Sem instrução
# 24115  2022  TO    Preta     00 a 17 anos     Ensino médio completo
# 24116  2022  TO    Preta     00 a 17 anos  Ensino superior completo
#
#        Violência Sexual (SINESP) População Mulheres (PNAD)
# 0                              0                       368
# ...

# %%
#excluir as UFs SP, MG, RJ, DF
estado_a_remover_sinesp = dados_sinesp[(dados_sinesp['UF'] == 'SP')|(dados_sinesp['UF'] == 'RJ')|(dados_sinesp['UF'] == 'MG')|(dados_sinesp['UF'] == 'DF')].index

sinesp_oficial = dados_sinesp.drop(estado_a_remover_sinesp)
sinesp_oficial
# Out:
#         Ano  UF Raça/Cor     Faixa etária              Escolaridade  \
# 0      2011  AC  Amarela  60 anos ou mais             Sem instrução
# 1      2011  AC  Amarela  60 anos ou mais  Até fundamental completo
# 2      2011  AC   Branca  60 anos ou mais             Sem instrução
# 3      2011  AC   Branca  60 anos ou mais  Até fundamental completo
# 4      2011  AC   Branca  60 anos ou mais     Ensino médio completo
# ...     ...  ..      ...              ...                       ...
# 24112  2022  TO    Parda     00 a 17 anos             Sem instrução
# 24113  2022  TO    Parda     00 a 17 anos  Ensino superior completo
# 24114  2022  TO    Preta     00 a 17 anos             Sem instrução
# 24115  2022  TO    Preta     00 a 17 anos     Ensino médio completo
# 24116  2022  TO    Preta     00 a 17 anos  Ensino superior completo
#
#        Violência Sexual (SINESP) População Mulheres (PNAD)
# 0                              0                       368
# ...

# %%
#renomeando colunas

sinesp_oficial.rename(columns={'Raça/Cor': 'raça_cor'}, inplace=True)
sinesp_oficial.rename(columns={'Violência Sexual (SINESP)': 'Sinesp'}, inplace=True)
sinesp_oficial.rename(columns={'Faixa etária': 'faixa_etaria'}, inplace=True)
sinesp_oficial
# Out:
#         Ano  UF raça_cor     faixa_etaria              Escolaridade  Sinesp  \
# 0      2011  AC  Amarela  60 anos ou mais             Sem instrução       0
# 1      2011  AC  Amarela  60 anos ou mais  Até fundamental completo       0
# 2      2011  AC   Branca  60 anos ou mais             Sem instrução       0
# 3      2011  AC   Branca  60 anos ou mais  Até fundamental completo       0
# 4      2011  AC   Branca  60 anos ou mais     Ensino médio completo       0
# ...     ...  ..      ...              ...                       ...     ...
# 24112  2022  TO    Parda     00 a 17 anos             Sem instrução       0
# 24113  2022  TO    Parda     00 a 17 anos  Ensino superior completo       0
# 24114  2022  TO    Preta     00 a 17 anos             Sem instrução       0
# 24115  2022  TO    Preta     00 a 17 anos     Ensino médio completo       0
# 24116  2022  TO    Preta     00 a 17 anos  Ensino superior completo       0
#
#       População Mulheres (PNAD)
# ...

# %%
#groupby raca
sinesp_raca = sinesp_oficial.groupby(["Ano", "raça_cor"])[["Sinesp"]].sum().reset_index()
sinesp_raca
# Out:
#      Ano        raça_cor  Sinesp
# 0   2011         Amarela       0
# 1   2011          Branca       0
# 2   2011        Indígena       0
# 3   2011           Parda       0
# 4   2011           Preta       0
# ..   ...             ...     ...
# 68  2022        Indígena      43
# 69  2022          Outros     111
# 70  2022           Parda    3102
# 71  2022           Preta     565
# 72  2022  Sem informação    4541
#
# [73 rows x 3 columns]

# %%
import plotly.express as px
# Convertendo a coluna 'Ano' para string
sinesp_raca['Ano'] = sinesp_raca['Ano'].astype(str)

# %%
#gráfico sinesp raça - linear
grafico_sinesp_raca_linear = px.line(sinesp_raca, x="Ano", y="Sinesp", color='raça_cor', markers=True,color_discrete_sequence=['#800080','#FFA500','#FFFF00','#008000','#0000FF','#FF0000'],
                       title="Número de Casos por Raça/Cor ao Longo dos Anos (Escala Linear) do Sinesp",
                       labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "raça_cor": "Raça/Cor"})
grafico_sinesp_raca_linear.update_traces(text=sinesp_raca['Sinesp'], hoverinfo='text+x+y')
grafico_sinesp_raca_linear.update_yaxes(type='linear', tickmode='linear', tick0=0, dtick=500)  # Definindo intervalos de 500

# Exibindo o gráfico
grafico_sinesp_raca_linear.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Seu código para criar o gráfico
grafico_sinesp_raca_linear = px.line(
    sinesp_raca,
    x="Ano",
    y="Sinesp",
    color='raça_cor',
    markers=True,
    color_discrete_sequence=['#800080', '#FFA500', '#FFFF00', '#008000', '#0000FF', '#FF0000'],
    title="Número de Casos por Raça/Cor ao Longo dos Anos (Escala Linear) do Sinesp",
    labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "raça_cor": "Raça/Cor"}
)

grafico_sinesp_raca_linear.update_traces
# Out:
# <bound method Figure.update_traces of Figure({
#     'data': [{'hovertemplate': 'Raça/Cor=Amarela<br>Ano=%{x}<br>Número de Casos (Sinesp)=%{y}<extra></extra>',
#               'legendgroup': 'Amarela',
#               'line': {'color': '#800080', 'dash': 'solid'},
#               'marker': {'symbol': 'circle'},
#               'mode': 'markers+lines',
#               'name': 'Amarela',
#               'orientation': 'v',
#               'showlegend': True,
#               'type': 'scatter',
#               'x': array(['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#                           '2020', '2021', '2022'], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 0,  0,  0,  0,  0,  0,  0, 35, 23, 26, 32, 38]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Raça/Cor=Branca<br>Ano=%{x}<br>Número de Casos (Sinesp)=%{y}<extra></extra>',
#               'legendgroup': 'Branca',
# ...

# %%
#groupby 2: escolaridade
sinesp_escolaridade = sinesp_oficial.groupby(["Ano", "Escolaridade"])[["Sinesp"]].sum().reset_index()
sinesp_escolaridade
# Out:
#      Ano              Escolaridade  Sinesp
# 0   2011  Até fundamental completo       0
# 1   2011     Ensino médio completo       0
# 2   2011  Ensino superior completo       0
# 3   2011            Sem informação       0
# 4   2011             Sem instrução       0
# 5   2012  Até fundamental completo       0
# 6   2012     Ensino médio completo       0
# 7   2012  Ensino superior completo       0
# 8   2012            Sem informação       0
# 9   2012             Sem instrução       0
# 10  2013  Até fundamental completo       0
# 11  2013     Ensino médio completo       0
# 12  2013  Ensino superior completo       0
# 13  2013            Sem informação       0
# 14  2013             Sem instrução       0
# 15  2014  Até fundamental completo       0
# 16  2014     Ensino médio completo       0
# 17  2014  Ensino superior completo       0
# 18  2014            Sem informação       0
# 19  2014             Sem instrução       0
# 20  2015  Até fundamental completo       0
# ...

# %%
#gráfico sinesp escolaridade - linear

sinesp_escolaridade['Ano'] = sinesp_escolaridade['Ano'].astype(str)

grafico_sinesp_escolaridade = px.line(sinesp_escolaridade, x="Ano", y="Sinesp", color='Escolaridade', markers = True,color_discrete_sequence=['#FF7F7F','#779ECB','#77DD77','#CBAACB','#FFB347'],
              title="Número de Casos por Escolaridade ao Longo dos Anos (Escala Linear) do SINESP",
              labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "escolaridade": "Escolaridade"})
grafico_sinesp_escolaridade.update_traces(text=sinesp_escolaridade['Sinesp'], hoverinfo='text+x+y')
grafico_sinesp_escolaridade.update_yaxes(type='linear')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#groupby 3: faixa etária
sinesp_faixa = sinesp_oficial.groupby(["Ano", "faixa_etaria"])[["Sinesp"]].sum().reset_index()
sinesp_faixa
# Out:
#      Ano     faixa_etaria  Sinesp
# 0   2011     00 a 17 anos       0
# 1   2011     18 a 29 anos       0
# 2   2011     30 a 59 anos       0
# 3   2011  60 anos ou mais       0
# 4   2012     00 a 17 anos       0
# 5   2012     18 a 29 anos       0
# 6   2012     30 a 59 anos       0
# 7   2012  60 anos ou mais       0
# 8   2013     00 a 17 anos       0
# 9   2013     18 a 29 anos       0
# 10  2013     30 a 59 anos       0
# 11  2013  60 anos ou mais       0
# 12  2014     00 a 17 anos       0
# 13  2014     18 a 29 anos       0
# 14  2014     30 a 59 anos       0
# 15  2014  60 anos ou mais       0
# 16  2015     00 a 17 anos       0
# 17  2015     18 a 29 anos       0
# 18  2015     30 a 59 anos       0
# 19  2015  60 anos ou mais       0
# 20  2016     00 a 17 anos       0
# 21  2016     18 a 29 anos       0
# 22  2016     30 a 59 anos       0
# 23  2016  60 anos ou mais       0
# 24  2017     00 a 17 anos       0
# 25  2017     18 a 29 anos       0
# ...

# %%
#gráfico faixa etária sinesp - escala linear

sinesp_faixa['Ano'] = sinesp_faixa['Ano'].astype(str)

grafico_sinesp_faixa = px.line(sinesp_faixa, x="Ano", y="Sinesp", color='faixa_etaria', markers = True,
              title="Número de Casos por Faixa Etária ao Longo dos Anos (Escala Linear) do SINESP",
              labels={"Sinesp": "Número de Casos (Sinesp)", "Ano": "Ano", "faixa_etaria": "Faixa Etária"})
grafico_sinesp_faixa.update_traces(text=sinesp_faixa['Sinesp'], hoverinfo='text+x+y')
grafico_sinesp_faixa.update_yaxes(type='linear')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # SINAN

# %%
sinan = pd.read_excel('sinan.xlsx')

# %%
#descobrindo o tipo dos dados
sinan.dtypes
# Out:
# Ano                           int64
# UF                           object
# Raça/Cor                     object
# Faixa etária                 object
# Escolaridade                 object
# Violência Sexual (SINAN)      int64
# População Mulheres (PNAD)    object
# dtype: object

# %%
sinan.head(10)
# Out:
#     Ano  UF  Raça/Cor     Faixa etária              Escolaridade  \
# 0  2011  AC   Amarela  60 anos ou mais             Sem instrução
# 1  2011  AC   Amarela  60 anos ou mais  Até fundamental completo
# 2  2011  AC    Branca  60 anos ou mais             Sem instrução
# 3  2011  AC    Branca  60 anos ou mais  Até fundamental completo
# 4  2011  AC    Branca  60 anos ou mais     Ensino médio completo
# 5  2011  AC    Branca  60 anos ou mais  Ensino superior completo
# 6  2011  AC  Indígena  60 anos ou mais             Sem instrução
# 7  2011  AC     Parda  60 anos ou mais             Sem instrução
# 8  2011  AC     Parda  60 anos ou mais  Até fundamental completo
# 9  2011  AC     Parda  60 anos ou mais     Ensino médio completo
#
#    Violência Sexual (SINAN) População Mulheres (PNAD)
# 0                         0                       368
# 1                         0                       185
# 2                         0                      3871
# ...

# %%
ano_sinan_remover = sinan[( sinan['Ano'] == 2011) | ( sinan['Ano'] == 2012) | ( sinan['Ano'] == 2013)  | ( sinan['Ano'] == 2014) | ( sinan['Ano'] == 2015) | ( sinan['Ano'] == 2016) |( sinan['Ano'] == 2017) | ( sinan['Ano'] == 2023)].index

dados_sinan = sinan.drop(ano_sinan_remover)
dados_sinan
# Out:
#         Ano  UF        Raça/Cor     Faixa etária              Escolaridade  \
# 15702  2018  AC         Amarela  60 anos ou mais  Até fundamental completo
# 15703  2018  AC         Amarela  60 anos ou mais  Ensino superior completo
# 15704  2018  AC          Branca  60 anos ou mais             Sem instrução
# 15705  2018  AC          Branca  60 anos ou mais  Até fundamental completo
# 15706  2018  AC          Branca  60 anos ou mais     Ensino médio completo
# ...     ...  ..             ...              ...                       ...
# 27512  2022  TO           Preta     00 a 17 anos            Sem informação
# 27513  2022  TO  Sem informação     00 a 17 anos  Até fundamental completo
# 27514  2022  TO  Sem informação     00 a 17 anos     Ensino médio completo
# 27515  2022  TO  Sem informação     00 a 17 anos  Ensino superior completo
# 27516  2022  TO  Sem informação     00 a 17 anos            Sem informação
#
#        Violência Sexual (SINAN) População Mulheres (PNAD)
# ...

# %%
estado_a_remover = dados_sinan[(dados_sinan['UF'] == 'SP')|(dados_sinan['UF'] == 'RJ')|(dados_sinan['UF'] == 'MG')|(dados_sinan['UF'] == 'DF')].index

sinan_oficial = dados_sinan.drop(estado_a_remover)
sinan_oficial
# Out:
#         Ano  UF        Raça/Cor     Faixa etária              Escolaridade  \
# 15702  2018  AC         Amarela  60 anos ou mais  Até fundamental completo
# 15703  2018  AC         Amarela  60 anos ou mais  Ensino superior completo
# 15704  2018  AC          Branca  60 anos ou mais             Sem instrução
# 15705  2018  AC          Branca  60 anos ou mais  Até fundamental completo
# 15706  2018  AC          Branca  60 anos ou mais     Ensino médio completo
# ...     ...  ..             ...              ...                       ...
# 27512  2022  TO           Preta     00 a 17 anos            Sem informação
# 27513  2022  TO  Sem informação     00 a 17 anos  Até fundamental completo
# 27514  2022  TO  Sem informação     00 a 17 anos     Ensino médio completo
# 27515  2022  TO  Sem informação     00 a 17 anos  Ensino superior completo
# 27516  2022  TO  Sem informação     00 a 17 anos            Sem informação
#
#        Violência Sexual (SINAN) População Mulheres (PNAD)
# ...

# %%
sinan_oficial.rename(columns={'Raça/Cor': 'raça_cor'}, inplace=True)
sinan_oficial.rename(columns={'Violência Sexual (SINAN)': 'Sinan'}, inplace=True)
sinan_oficial.rename(columns={'Faixa etária': 'faixa_etaria'}, inplace=True)
sinan_oficial
# Out:
#         Ano  UF        raça_cor     faixa_etaria              Escolaridade  \
# 15702  2018  AC         Amarela  60 anos ou mais  Até fundamental completo
# 15703  2018  AC         Amarela  60 anos ou mais  Ensino superior completo
# 15704  2018  AC          Branca  60 anos ou mais             Sem instrução
# 15705  2018  AC          Branca  60 anos ou mais  Até fundamental completo
# 15706  2018  AC          Branca  60 anos ou mais     Ensino médio completo
# ...     ...  ..             ...              ...                       ...
# 27512  2022  TO           Preta     00 a 17 anos            Sem informação
# 27513  2022  TO  Sem informação     00 a 17 anos  Até fundamental completo
# 27514  2022  TO  Sem informação     00 a 17 anos     Ensino médio completo
# 27515  2022  TO  Sem informação     00 a 17 anos  Ensino superior completo
# 27516  2022  TO  Sem informação     00 a 17 anos            Sem informação
#
#        Sinan População Mulheres (PNAD)
# ...

# %%
#groupby 1: raça
sinan_raca = sinan_oficial.groupby(["Ano", "raça_cor"])[["Sinan"]].sum().reset_index()
sinan_raca
# Out:
#      Ano        raça_cor  Sinan
# 0   2018         Amarela    172
# 1   2018          Branca   6913
# 2   2018        Indígena    275
# 3   2018           Parda  10332
# 4   2018           Preta   1519
# 5   2018  Sem informação    686
# 6   2019         Amarela    173
# 7   2019          Branca   7696
# 8   2019        Indígena    380
# 9   2019           Parda  11528
# 10  2019           Preta   1746
# 11  2019  Sem informação    779
# 12  2020         Amarela    216
# 13  2020          Branca   6288
# 14  2020        Indígena    280
# 15  2020           Parda  10355
# 16  2020           Preta   1471
# 17  2020  Sem informação    688
# 18  2021         Amarela    235
# 19  2021          Branca   7225
# 20  2021        Indígena    339
# 21  2021           Parda  12910
# 22  2021           Preta   1833
# 23  2021  Sem informação    796
# 24  2022         Amarela    240
# 25  2022          Branca   9192
# 26  2022        Indígena    501
# 27  2022           Parda  15547
# ...

# %%
#gráfico sinan raça - linear
import numpy as np

sinan_raca['Ano'] = sinan_raca['Ano'].astype(str)
grafico_sinan_raca_linear = px.line(sinan_raca, x="Ano", y="Sinan", color='raça_cor', markers=True, color_discrete_sequence=['#800080','#FFA500','#FFFF00','#008000','#0000FF','#FF0000'],
              title="Número de Casos por Raça/Cor ao Longo dos Anos (Escala Linear) do SINAN",
              labels={"Sinan": "Número de Casos (Sinan)", "Ano": "Ano", "raça_cor": "Raça/Cor"})

grafico_sinan_raca_linear.update_traces(text=sinan_raca['Sinan'], hoverinfo='text+x+y')

# Definindo os valores e os textos do eixo Y manualmente
max_value = sinan_raca['Sinan'].max()
tick_values = np.arange(0, max_value + 2000, 2000)  # Isso criará um array de 0 até o valor máximo, com incrementos de 500
tick_texts = [f'{int(value)}' for value in tick_values]  # Isso converte os valores para texto sem a abreviação 'k'

# Aplicando as configurações ao eixo Y
grafico_sinan_raca_linear.update_yaxes(type='linear', tickmode='array', tickvals=tick_values, ticktext=tick_texts)

# Exibindo o gráfico
grafico_sinan_raca_linear.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#groupby 2: escolaridade
sinan_escolaridade = sinan_oficial.groupby(["Ano", "Escolaridade"])[["Sinan"]].sum().reset_index()
sinan_escolaridade
# Out:
#      Ano              Escolaridade  Sinan
# 0   2018  Até fundamental completo   2761
# 1   2018     Ensino médio completo   8424
# 2   2018  Ensino superior completo   2085
# 3   2018            Sem informação   6627
# 4   2018             Sem instrução      0
# 5   2019  Até fundamental completo   2986
# 6   2019     Ensino médio completo   9315
# 7   2019  Ensino superior completo   2475
# 8   2019            Sem informação   7526
# 9   2019             Sem instrução      0
# 10  2020  Até fundamental completo   2510
# 11  2020     Ensino médio completo   7888
# 12  2020  Ensino superior completo   2170
# 13  2020            Sem informação   6730
# 14  2020             Sem instrução      0
# 15  2021  Até fundamental completo   2902
# 16  2021     Ensino médio completo   9941
# 17  2021  Ensino superior completo   2520
# 18  2021            Sem informação   7975
# 19  2021             Sem instrução      0
# 20  2022  Até fundamental completo   2381
# ...

# %%
#gráfico sinan escolaridade - linear
sinan_escolaridade['Ano'] = sinan_escolaridade['Ano'].astype(str)

grafico_sinan_escolaridade = px.line(sinan_escolaridade, x="Ano", y="Sinan", color='Escolaridade', markers=True,color_discrete_sequence=['#FF7F7F','#779ECB','#77DD77','#CBAACB','#FFB347'],
              title="Número de Casos por Escolaridade ao Longo dos Anos (Escala Linear) do SINAN",
              labels={"Sinan": "Número de Casos (Sinan)", "Ano": "Ano", "Escolaridade": "Escolaridade"})

grafico_sinan_escolaridade.update_traces(text=sinan_escolaridade['Sinan'], hoverinfo='text+x+y')
# Definindo os valores e os textos do eixo Y manualmente
max_value = sinan_escolaridade['Sinan'].max()
tick_values = np.arange(0, max_value + 2000, 2000)  # Isso criará um array de 0 até o valor máximo, com incrementos de 500
tick_texts = [f'{int(value)}' for value in tick_values]  # Isso converte os valores para texto sem a abreviação 'k'

# Aplicando as configurações ao eixo Y
grafico_sinan_escolaridade.update_yaxes(type='linear', tickmode='array', tickvals=tick_values, ticktext=tick_texts)

# Exibindo o gráfico
grafico_sinan_escolaridade.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#groupby 3: faixa etária
sinan_faixa = sinan_oficial.groupby(["Ano", "faixa_etaria"])[["Sinan"]].sum().reset_index()
sinan_faixa
# Out:
#      Ano     faixa_etaria  Sinan
# 0   2018     00 a 17 anos  14241
# 1   2018     18 a 29 anos   3143
# 2   2018     30 a 59 anos   2330
# 3   2018  60 anos ou mais    183
# 4   2019     00 a 17 anos  15808
# 5   2019     18 a 29 anos   3540
# 6   2019     30 a 59 anos   2719
# 7   2019  60 anos ou mais    207
# 8   2019   Sem informação     28
# 9   2020     00 a 17 anos  13551
# 10  2020     18 a 29 anos   3213
# 11  2020     30 a 59 anos   2327
# 12  2020  60 anos ou mais    207
# 13  2021     00 a 17 anos  16820
# 14  2021     18 a 29 anos   3457
# 15  2021     30 a 59 anos   2856
# 16  2021  60 anos ou mais    205
# 17  2022     00 a 17 anos  20584
# 18  2022     18 a 29 anos   4449
# 19  2022     30 a 59 anos   3592
# 20  2022  60 anos ou mais    251

# %%
#gráfico sinan faixa etária -  linear

sinan_faixa['Ano'] = sinan_faixa['Ano'].astype(str)

grafico_sinan_faixa = px.line(sinan_faixa, x="Ano", y="Sinan", color='faixa_etaria', markers=True,
              title="Número de Casos por Faixa Etária ao Longo dos Anos (Escala Linear) do SINAN",
              labels={"Sinan": "Número de Casos (Sinan)", "Ano": "Ano", "Faixa Etária": "faixa_etária"})
# Definindo os valores e os textos do eixo Y manualmente
max_value = sinan_faixa['Sinan'].max()
tick_values = np.arange(0, max_value + 2000, 2000)  # Isso criará um array de 0 até o valor máximo, com incrementos de 500
tick_texts = [f'{int(value)}' for value in tick_values]  # Isso converte os valores para texto sem a abreviação 'k'

# Aplicando as configurações ao eixo Y
grafico_sinan_faixa.update_yaxes(type='linear', tickmode='array', tickvals=tick_values, ticktext=tick_texts)

# Exibindo o gráfico
grafico_sinan_faixa.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#groupby para mapa de casos

sinesp_mapa = sinesp_oficial.groupby(["UF"])[["Sinesp"]].sum().reset_index()
sinesp_mapa.to_csv('sinesp_mapa.csv', index=False)

# %%
sinan_mapa = sinan_oficial.groupby(["UF"])[["Sinan"]].sum().reset_index()
sinan_mapa.to_csv('sinan_mapa.csv', index=False)
